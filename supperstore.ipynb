# %%
import pandas as pd

df = pd.read_excel("C:/Users/Asus/OneDrive/Desktop/Documents/Superstore Dataset.xlsx")

print(df)
# Out:
#       Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 0                    1  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 1                    2  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 2                    3  CA-2019-138688 2019-06-12 2019-06-16    Second Class
# 3                   13  CA-2020-114412 2020-04-15 2020-04-20  Standard Class
# 4                   14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class
# ...                ...             ...        ...        ...             ...
# 5894              9989  CA-2020-163629 2020-11-17 2020-11-21  Standard Class
# 5895              9991  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5896              9992  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5897              9993  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5898              9994  CA-2020-119914 2020-05-04 2020-05-09    Second Class
#
# ...

# %%
print(df.tail(3))
# Out:
#       Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 5896              9992  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5897              9993  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5898              9994  CA-2020-119914 2020-05-04 2020-05-09    Second Class
#
#      Customer ID Customer Name   Segment        Country         City  \
# 5896    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa
# 5897    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa
# 5898    CC-12220  Chris Cortes  Consumer  United States  Westminster
#
#            State Region       Product ID         Category Sub-Category  \
# 5896  California   West  TEC-PH-10003645       Technology       Phones
# 5897  California   West  OFF-PA-10004041  Office Supplies        Paper
# 5898  California   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name    Sales  Quantity  \
# ...

# %%
df.count("columns")
# Out:
# 0       19
# 1       19
# 2       19
# 3       19
# 4       19
#         ..
# 5894    19
# 5895    19
# 5896    19
# 5897    19
# 5898    19
# Length: 5899, dtype: int64

# %%
print(df.shape)
# Out:
# (5899, 19)

# %%
print(df.columns)
# Out:
# Index(['Row ID+O6G3A1:R6', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Profit'],
#       dtype='object')

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of       Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 0                    1  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 1                    2  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 2                    3  CA-2019-138688 2019-06-12 2019-06-16    Second Class
# 3                   13  CA-2020-114412 2020-04-15 2020-04-20  Standard Class
# 4                   14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class
# ...                ...             ...        ...        ...             ...
# 5894              9989  CA-2020-163629 2020-11-17 2020-11-21  Standard Class
# 5895              9991  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5896              9992  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5897              9993  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5898              9994  CA-2020-119914 2020-05-04 2020-05-09    Second Class
#
# ...

# %%
print(df.isnull())
# Out:
#       Row ID+O6G3A1:R6  Order ID  Order Date  Ship Date  Ship Mode  \
# 0                False     False       False      False      False
# 1                False     False       False      False      False
# 2                False     False       False      False      False
# 3                False     False       False      False      False
# 4                False     False       False      False      False
# ...                ...       ...         ...        ...        ...
# 5894             False     False       False      False      False
# 5895             False     False       False      False      False
# 5896             False     False       False      False      False
# 5897             False     False       False      False      False
# 5898             False     False       False      False      False
#
#       Customer ID  Customer Name  Segment  Country   City  State  Region  \
# 0           False          False    False    False  False  False   False
# ...

# %%
print(df.isna().any().any())
# Out:
# False

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.head())
# Out:
#    Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 0                 1  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 1                 2  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 2                 3  CA-2019-138688 2019-06-12 2019-06-16    Second Class
# 3                13  CA-2020-114412 2020-04-15 2020-04-20  Standard Class
# 4                14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class
#
#   Customer ID    Customer Name    Segment        Country         City  \
# 0    CG-12520      Claire Gute   Consumer  United States    Henderson
# 1    CG-12520      Claire Gute   Consumer  United States    Henderson
# 2    DV-13045  Darrin Van Huff  Corporate  United States  Los Angeles
# 3    AA-10480     Andrew Allen   Consumer  United States      Concord
# 4    IM-15070     Irene Maddox   Consumer  United States      Seattle
#
#             State Region       Product ID         Category Sub-Category  \
# ...

# %%
df.rename(columns={'Row ID+O6G3A1:R6':'Row_ID'},inplace=True)
df.to_excel("C:/Users/Asus/OneDrive/Desktop/Documents/Superstore Dataset.xlsx", index=False)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         5899 non-null   int64
#  1   Order ID       5899 non-null   object
#  2   Order Date     5899 non-null   datetime64[ns]
#  3   Ship Date      5899 non-null   datetime64[ns]
#  4   Ship Mode      5899 non-null   object
#  5   Customer ID    5899 non-null   object
#  6   Customer Name  5899 non-null   object
#  7   Segment        5899 non-null   object
#  8   Country        5899 non-null   object
#  9   City           5899 non-null   object
#  10  State          5899 non-null   object
#  11  Region         5899 non-null   object
#  12  Product ID     5899 non-null   object
#  13  Category       5899 non-null   object
#  14  Sub-Category   5899 non-null   object
#  15  Product Name   5899 non-null   object
#  16  Sales          5899 non-null   float64
# ...

# %%
if df.Sales.any().any() <0:
    print("negative")
print("positive")
# Out:
# positive

# %%
if df.Profit.any().any() <0:
    print("negative")
print("positive")
# Out:
# positive

# %%
if df.Quantity.any().any() ==0:
    print("negative")
print("positive")
# Out:
# positive

# %%
if df['Order Date' ,'Ship Date'].any()=='%d-%m-%y':
    print("True")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Order Date', 'Ship Date')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ...

# %%
df.columns=['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
       'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
       'Region', 'Product ID', 'Category', 'Sub-Category', 'Product_Name',
       'Sales', 'Quantity', 'Profit']

# %%
df.info()
df.to_excel("C:/Users/Asus/OneDrive/Desktop/Documents/Superstore Dataset.xlsx", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         5899 non-null   int64
#  1   Order_ID       5899 non-null   object
#  2   Order_Date     5899 non-null   datetime64[ns]
#  3   Ship_Date      5899 non-null   datetime64[ns]
#  4   Ship_Mode      5899 non-null   object
#  5   Customer_ID    5899 non-null   object
#  6   Customer_Name  5899 non-null   object
#  7   Segment        5899 non-null   object
#  8   Country        5899 non-null   object
#  9   City           5899 non-null   object
#  10  State          5899 non-null   object
#  11  Region         5899 non-null   object
#  12  Product ID     5899 non-null   object
#  13  Category       5899 non-null   object
#  14  Sub-Category   5899 non-null   object
#  15  Product_Name   5899 non-null   object
#  16  Sales          5899 non-null   float64
# ...

# %%
df.Sales.min()
# Out:
# 0.44399999999999995

# %%
df.Sales.max()
# Out:
# 17499.949999999997

# %%
df.Quantity.min()
# Out:
# 1

# %%
df.Quantity.max()
# Out:
# 14

# %%
df.Profit.min()
# Out:
# -6599.978000000001

# %%
df.Profit.max()
# Out:
# 8399.975999999999

# %%
df.Order_Date.max()
# Out:
# Timestamp('2020-12-30 00:00:00')

# %%
df.Order_Date.min()
# Out:
# Timestamp('2019-01-02 00:00:00')

# %%
if df.Order_Date.any().any()<df.Ship_Date.any().any():
    print("True")
else:
    print("s")
# Out:
# s
# C:\Users\Asus\AppData\Local\Temp\ipykernel_2416\3919678299.py:1: FutureWarning: 'any' with datetime64 dtypes is deprecated and will raise in a future version. Use (obj != pd.Timestamp(0)).any() instead.
#   if df.Order_Date.any().any()<df.Ship_Date.any().any():

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         5899 non-null   int64
#  1   Order_ID       5899 non-null   object
#  2   Order_Date     5899 non-null   datetime64[ns]
#  3   Ship_Date      5899 non-null   datetime64[ns]
#  4   Ship_Mode      5899 non-null   object
#  5   Customer_ID    5899 non-null   object
#  6   Customer_Name  5899 non-null   object
#  7   Segment        5899 non-null   object
#  8   Country        5899 non-null   object
#  9   City           5899 non-null   object
#  10  State          5899 non-null   object
#  11  Region         5899 non-null   object
#  12  Product ID     5899 non-null   object
#  13  Category       5899 non-null   object
#  14  Sub-Category   5899 non-null   object
#  15  Product_Name   5899 non-null   object
#  16  Sales          5899 non-null   float64
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df[['Order_Year','Order_Month','Order_Date']]=df['Order_Date'].astype(str).str.split('-',expand=True)
#       2 print(df)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4310, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_frame(key, value)
#    4309 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4310     self._setitem_array(key, value)
#    4311 elif isinstance(value, DataFrame):
#    4312     self._set_item_frame_value(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4352, in DataFrame._setitem_array(self, key, value)
#    4347 else:
#    4348     # Note: unlike self.iloc[:, indexer] = value, this will
#    4349     #  never try to overwrite values inplace
#    4351     if isinstance(value, DataFrame):
# ...

# %%
df["Order_Date"] = df["Order_Year"].astype(str) + '-' + df["Order_Month"].astype(str) + '-' + df["Order_Date"].astype(str)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Order_Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         5899 non-null   int64
#  1   Order_ID       5899 non-null   object
#  2   Order_Date     5899 non-null   datetime64[ns]
#  3   Ship_Date      5899 non-null   datetime64[ns]
#  4   Ship_Mode      5899 non-null   object
#  5   Customer_ID    5899 non-null   object
#  6   Customer_Name  5899 non-null   object
#  7   Segment        5899 non-null   object
#  8   Country        5899 non-null   object
#  9   City           5899 non-null   object
#  10  State          5899 non-null   object
#  11  Region         5899 non-null   object
#  12  Product ID     5899 non-null   object
#  13  Category       5899 non-null   object
#  14  Sub-Category   5899 non-null   object
#  15  Product_Name   5899 non-null   object
#  16  Sales          5899 non-null   float64
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 1          2  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 2          3  CA-2019-138688 2019-06-12 2019-06-16    Second Class
# 3         13  CA-2020-114412 2020-04-15 2020-04-20  Standard Class
# 4         14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class
# ...      ...             ...        ...        ...             ...
# 5894    9989  CA-2020-163629 2020-11-17 2020-11-21  Standard Class
# 5895    9991  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5896    9992  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5897    9993  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5898    9994  CA-2020-119914 2020-05-04 2020-05-09    Second Class
#
#      Customer_ID    Customer_Name    Segment        Country         City  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         5899 non-null   int64
#  1   Order_ID       5899 non-null   object
#  2   Order_Date     5899 non-null   object
#  3   Ship_Date      5899 non-null   datetime64[ns]
#  4   Ship_Mode      5899 non-null   object
#  5   Customer_ID    5899 non-null   object
#  6   Customer_Name  5899 non-null   object
#  7   Segment        5899 non-null   object
#  8   Country        5899 non-null   object
#  9   City           5899 non-null   object
#  10  State          5899 non-null   object
#  11  Region         5899 non-null   object
#  12  Product ID     5899 non-null   object
#  13  Category       5899 non-null   object
#  14  Sub-Category   5899 non-null   object
#  15  Product_Name   5899 non-null   object
#  16  Sales          5899 non-null   float64
# ...

# %%
df['Ship_Date']=pd.to_datetime(df["Ship_Date"],format='%d,%m,%y')

# %%
df.info
# Out:
# <bound method DataFrame.info of       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 1          2  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 2          3  CA-2019-138688 2019-06-12 2019-06-16    Second Class
# 3         13  CA-2020-114412 2020-04-15 2020-04-20  Standard Class
# 4         14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class
# ...      ...             ...        ...        ...             ...
# 5894    9989  CA-2020-163629 2020-11-17 2020-11-21  Standard Class
# 5895    9991  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5896    9992  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5897    9993  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5898    9994  CA-2020-119914 2020-05-04 2020-05-09    Second Class
#
#      Customer_ID    Customer_Name    Segment        Country         City  \
# ...

# %%
df['Order_Date'] = pd.to_datetime(df["Order_Date"], dayfirst=True)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 1          2  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 2          3  CA-2019-138688 2019-06-12 2019-06-16    Second Class
# 3         13  CA-2020-114412 2020-04-15 2020-04-20  Standard Class
# 4         14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class
# ...      ...             ...        ...        ...             ...
# 5894    9989  CA-2020-163629 2020-11-17 2020-11-21  Standard Class
# 5895    9991  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5896    9992  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5897    9993  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5898    9994  CA-2020-119914 2020-05-04 2020-05-09    Second Class
#
#      Customer_ID    Customer_Name    Segment        Country         City  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         5899 non-null   int64
#  1   Order_ID       5899 non-null   object
#  2   Order_Date     5899 non-null   datetime64[ns]
#  3   Ship_Date      5899 non-null   datetime64[ns]
#  4   Ship_Mode      5899 non-null   object
#  5   Customer_ID    5899 non-null   object
#  6   Customer_Name  5899 non-null   object
#  7   Segment        5899 non-null   object
#  8   Country        5899 non-null   object
#  9   City           5899 non-null   object
#  10  State          5899 non-null   object
#  11  Region         5899 non-null   object
#  12  Product ID     5899 non-null   object
#  13  Category       5899 non-null   object
#  14  Sub-Category   5899 non-null   object
#  15  Product_Name   5899 non-null   object
#  16  Sales          5899 non-null   float64
# ...

# %%
df['Order_Month'] = pd.to_datetime(df['Order_Date'], format='%m')
df.to_excel("C:/Users/Asus/OneDrive/Desktop/Documents/Superstore Dataset.xlsx", index=False)

# %%
df['Order_Year']=pd.to_datetime(df['Order_Date'],format='%y')
df.to_excel("C:/Users/Asus/OneDrive/Desktop/Documents/Superstore Dataset.xlsx", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         5899 non-null   int64
#  1   Order_ID       5899 non-null   object
#  2   Order_Date     5899 non-null   datetime64[ns]
#  3   Ship_Date      5899 non-null   datetime64[ns]
#  4   Ship_Mode      5899 non-null   object
#  5   Customer_ID    5899 non-null   object
#  6   Customer_Name  5899 non-null   object
#  7   Segment        5899 non-null   object
#  8   Country        5899 non-null   object
#  9   City           5899 non-null   object
#  10  State          5899 non-null   object
#  11  Region         5899 non-null   object
#  12  Product ID     5899 non-null   object
#  13  Category       5899 non-null   object
#  14  Sub-Category   5899 non-null   object
#  15  Product_Name   5899 non-null   object
#  16  Sales          5899 non-null   float64
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 1          2  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 2          3  CA-2019-138688 2019-06-12 2019-06-16    Second Class
# 3         13  CA-2020-114412 2020-04-15 2020-04-20  Standard Class
# 4         14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class
# ...      ...             ...        ...        ...             ...
# 5894    9989  CA-2020-163629 2020-11-17 2020-11-21  Standard Class
# 5895    9991  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5896    9992  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5897    9993  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5898    9994  CA-2020-119914 2020-05-04 2020-05-09    Second Class
#
#      Customer_ID    Customer_Name    Segment        Country         City  ...  \
# ...

# %%
# Month Number
df["Order_Month"] = df["Order_Date"].dt.month
df.to_excel("C:/Users/Asus/OneDrive/Desktop/Documents/Superstore Dataset.xlsx", index=False)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 1          2  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 2          3  CA-2019-138688 2019-06-12 2019-06-16    Second Class
# 3         13  CA-2020-114412 2020-04-15 2020-04-20  Standard Class
# 4         14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class
# ...      ...             ...        ...        ...             ...
# 5894    9989  CA-2020-163629 2020-11-17 2020-11-21  Standard Class
# 5895    9991  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5896    9992  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5897    9993  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5898    9994  CA-2020-119914 2020-05-04 2020-05-09    Second Class
#
#      Customer_ID    Customer_Name    Segment        Country         City  ...  \
# ...

# %%
# Month Number
df["Order_Year"] = df["Order_Date"].dt.year
df.to_excel("C:/Users/Asus/OneDrive/Desktop/Documents/Superstore Dataset.xlsx", index=False)

# %%
df["Month_Name"] = df["Order_Date"].dt.month_name()
df.to_excel("C:/Users/Asus/OneDrive/Desktop/Documents/Superstore Dataset.xlsx", index=False)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 1          2  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 2          3  CA-2019-138688 2019-06-12 2019-06-16    Second Class
# 3         13  CA-2020-114412 2020-04-15 2020-04-20  Standard Class
# 4         14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class
# ...      ...             ...        ...        ...             ...
# 5894    9989  CA-2020-163629 2020-11-17 2020-11-21  Standard Class
# 5895    9991  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5896    9992  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5897    9993  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5898    9994  CA-2020-119914 2020-05-04 2020-05-09    Second Class
#
#      Customer_ID    Customer_Name    Segment        Country         City  ...  \
# ...

# %%
df['Delivery_Days']=(df['Ship_Date']-df['Order_Date']).dt.days
df.to_excel("C:/Users/Asus/OneDrive/Desktop/Documents/Superstore Dataset.xlsx", index=False)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 1          2  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 2          3  CA-2019-138688 2019-06-12 2019-06-16    Second Class
# 3         13  CA-2020-114412 2020-04-15 2020-04-20  Standard Class
# 4         14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class
# ...      ...             ...        ...        ...             ...
# 5894    9989  CA-2020-163629 2020-11-17 2020-11-21  Standard Class
# 5895    9991  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5896    9992  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5897    9993  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5898    9994  CA-2020-119914 2020-05-04 2020-05-09    Second Class
#
#      Customer_ID    Customer_Name    Segment        Country         City  ...  \
# ...

# %%
df["Quarter"] = df["Order_Date"].dt.quarter
df.to_excel("C:/Users/Asus/OneDrive/Desktop/Documents/Superstore Dataset.xlsx", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         5899 non-null   int64
#  1   Order_ID       5899 non-null   object
#  2   Order_Date     5899 non-null   datetime64[ns]
#  3   Ship_Date      5899 non-null   datetime64[ns]
#  4   Ship_Mode      5899 non-null   object
#  5   Customer_ID    5899 non-null   object
#  6   Customer_Name  5899 non-null   object
#  7   Segment        5899 non-null   object
#  8   Country        5899 non-null   object
#  9   City           5899 non-null   object
#  10  State          5899 non-null   object
#  11  Region         5899 non-null   object
#  12  Product ID     5899 non-null   object
#  13  Category       5899 non-null   object
#  14  Sub-Category   5899 non-null   object
#  15  Product_Name   5899 non-null   object
#  16  Sales          5899 non-null   float64
# ...

# %%
df.Quarter
# Out:
# 0       4
# 1       4
# 2       2
# 3       2
# 4       4
#        ..
# 5894    4
# 5895    1
# 5896    1
# 5897    1
# 5898    2
# Name: Quarter, Length: 5899, dtype: int32

# %%
df[["Order_Date","Quarter"]]
# Out:
#      Order_Date  Quarter
# 0    2019-11-08        4
# 1    2019-11-08        4
# 2    2019-06-12        2
# 3    2020-04-15        2
# 4    2019-12-05        4
# ...         ...      ...
# 5894 2020-11-17        4
# 5895 2020-02-26        1
# 5896 2020-02-26        1
# 5897 2020-02-26        1
# 5898 2020-05-04        2
#
# [5899 rows x 2 columns]

# %%
print(df.Sales.sum())
print(df.Sales.sum()/df.count('rows'))
print(df.Sales.max())
print(df.Sales.min())
# Out:
# 1342420.8532
# Row_ID           227.567529
# Order_ID         227.567529
# Order_Date       227.567529
# Ship_Date        227.567529
# Ship_Mode        227.567529
# Customer_ID      227.567529
# Customer_Name    227.567529
# Segment          227.567529
# Country          227.567529
# City             227.567529
# State            227.567529
# Region           227.567529
# Product ID       227.567529
# Category         227.567529
# Sub-Category     227.567529
# Product_Name     227.567529
# Sales            227.567529
# Quantity         227.567529
# Profit           227.567529
# Order_Month      227.567529
# Order_Year       227.567529
# Month_Name       227.567529
# Quarter          227.567529
# dtype: float64
# 17499.949999999997
# 0.44399999999999995

# %%
df.groupby(["Order_Month","Month_Name"])["Sales"].sum()
# Out:
# Order_Month  Month_Name
# 1            January        62513.8650
# 2            February       43279.9484
# 3            March         110588.2278
# 4            April          75271.5751
# 5            May           101248.8382
# 6            June           93326.2597
# 7            July           84526.3790
# 8            August         94236.2623
# 9            September     161276.6769
# 10           October       137464.6682
# 11           November      197859.7908
# 12           December      180828.3618
# Name: Sales, dtype: float64

# %%
df.groupby(["Order_Year"])["Sales"].sum()
# Out:
# Order_Year
# 2019    609205.5980
# 2020    733215.2552
# Name: Sales, dtype: float64

# %%
df.groupby(["Quarter","Order_Year"])["Sales"].sum()
# Out:
# Quarter  Order_Year
# 1        2019           93237.1810
#          2020          123144.8602
# 2        2019          136082.3010
#          2020          133764.3720
# 3        2019          143787.3622
#          2020          196251.9560
# 4        2019          236098.7538
#          2020          280054.0670
# Name: Sales, dtype: float64

# %%
print(df.Profit.sum())
print(df.Profit.sum()/df.count("rows"))
print(df.Profit.max())
print(df.Profit.min())
# Out:
# 175234.44389999995
# Row_ID           29.705788
# Order_ID         29.705788
# Order_Date       29.705788
# Ship_Date        29.705788
# Ship_Mode        29.705788
# Customer_ID      29.705788
# Customer_Name    29.705788
# Segment          29.705788
# Country          29.705788
# City             29.705788
# State            29.705788
# Region           29.705788
# Product ID       29.705788
# Category         29.705788
# Sub-Category     29.705788
# Product_Name     29.705788
# Sales            29.705788
# Quantity         29.705788
# Profit           29.705788
# Order_Month      29.705788
# Order_Year       29.705788
# Month_Name       29.705788
# Quarter          29.705788
# dtype: float64
# 8399.975999999999
# -6599.978000000001

# %%
df.groupby(['Category'])['Profit'].sum()
# Out:
# Category
# Furniture           9978.3444
# Office Supplies    74797.8509
# Technology         90458.2486
# Name: Profit, dtype: float64

# %%
df.groupby(['Region'])['Profit'].sum()
# Out:
# Region
# Central    27450.0071
# East       53372.1575
# South      26551.7163
# West       67860.5630
# Name: Profit, dtype: float64

# %%
df.groupby(['Order_Month'])['Profit'].sum()
# Out:
# Order_Month
# 1      9965.2624
# 2      6618.4515
# 3     18363.8595
# 4      3911.1049
# 5     15004.7292
# 6     12973.7138
# 7     11385.4991
# 8     11103.0250
# 9     20320.2132
# 10    25518.4180
# 11    13701.5112
# 12    26368.6561
# Name: Profit, dtype: float64

# %%
df.groupby(['Product_Name'])['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Product_Name
# Canon imageCLASS 2200 Advanced Copier                 61599.824
# Hewlett Packard LaserJet 3310 Copier                  16079.732
# 3D Systems Cube Printer, 2nd Generation, Magenta      14299.890
# GBC Ibimaster 500 Manual ProClick Binding System      13621.542
# GBC DocuBind TL300 Electric Binding System            12737.258
# GBC DocuBind P400 Electric Binding System             12521.108
# Samsung Galaxy Mega 6.3                               12263.708
# HON 5400 Series Task Chairs for Big and Tall          11846.562
# Martin Yale Chadless Opener Electric Letter Opener    11825.902
# Global Troy Executive Leather Low-Back Tilter         10169.894
# Name: Sales, dtype: float64

# %%
df.groupby(['Product_Name'])['Profit'].sum().sort_values(ascending=False).head(10)
# Out:
# Product_Name
# Canon imageCLASS 2200 Advanced Copier                                 25199.9280
# Hewlett Packard LaserJet 3310 Copier                                   6407.8932
# 3D Systems Cube Printer, 2nd Generation, Magenta                       3717.9714
# HP Designjet T520 Inkjet Large Format Printer - 24" Color              2799.9840
# GBC DocuBind TL300 Electric Binding System                             2753.7593
# Ativa V4110MDD Micro-Cut Shredder                                      2400.9657
# Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room     2396.1805
# Plantronics CS510 - Over-the-Head monaural Wireless Headset System     2062.1875
# Canon PC1060 Personal Laser Copier                                     1889.9730
# Logitech Z-906 Speaker sys - home theater - 5.1-CH                     1847.9440
# Name: Profit, dtype: float64

# %%
a=df.groupby(['Product_Name'])['Profit'].sum().sort_values(ascending=False).tail(10)
print(a)
# Out:
# Product_Name
# Epson TM-T88V Direct Thermal Printer - Monochrome - Desktop          -935.9595
# Zebra GK420t Direct Thermal/Thermal Transfer Printer                 -938.2800
# Bretford “Just In Time” Height-Adjustable Multi-Task Work Tables     -964.1940
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables    -986.5625
# Martin Yale Chadless Opener Electric Letter Opener                  -1232.5588
# Ibico EPK-21 Electric Binding System                                -1285.1932
# Bush Advantage Collection Racetrack Conference Table                -2019.2396
# Lexmark MX611dhe Monochrome Laser Printer                           -2719.9840
# Cubify CubeX 3D Printer Triple Head Print                           -3839.9904
# Cubify CubeX 3D Printer Double Head Print                           -6239.9792
# Name: Profit, dtype: float64

# %%
df.groupby(['Sub-Category'])['Sales'].sum()
# Out:
# Sub-Category
# Accessories    101842.0860
# Appliances      68977.2470
# Art             14823.9760
# Binders        122471.3700
# Bookcases       56299.7462
# Chairs         179472.9980
# Copiers        112498.7980
# Envelopes        8108.4640
# Fasteners        1817.7280
# Furnishings     56789.2180
# Labels           6688.4560
# Machines        99451.5610
# Paper           48356.6120
# Phones         184302.5460
# Storage        128466.3180
# Supplies        30326.9860
# Tables         121726.7430
# Name: Sales, dtype: float64

# %%
df.Customer_ID.count()
# Out:
# np.int64(5899)

# %%
df.Customer_ID.head(10)
# Out:
# 0    CG-12520
# 1    CG-12520
# 2    DV-13045
# 3    AA-10480
# 4    IM-15070
# 5    KB-16585
# 6    KB-16585
# 7    SF-20065
# 8    EH-13945
# 9    EH-13945
# Name: Customer_ID, dtype: object

# %%
df.groupby(['Customer_ID'])['Profit'].sum()
# Out:
# Customer_ID
# AA-10315    -650.5971
# AA-10375     191.6403
# AA-10480     425.9418
# AA-10645     340.8478
# AB-10015     116.8680
#               ...
# XP-21865     394.4678
# YC-21895     464.8007
# YS-21880    1524.1125
# ZC-21910   -1668.6747
# ZD-21925     223.2533
# Name: Profit, Length: 773, dtype: float64

# %%
df.groupby(['Region'])['Sales'].sum()
# Out:
# Region
# Central    294527.5042
# East       393768.7260
# South      216516.0810
# West       437608.5420
# Name: Sales, dtype: float64

# %%
df.groupby(['State'])['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# State
# California      277940.2560
# New York        165767.0970
# Washington       85354.1800
# Texas            85107.9102
# Pennsylvania     75754.9500
# Michigan         53253.6840
# Ohio             48012.8600
# Illinois         45385.3300
# Indiana          43978.2300
# Florida          40047.9990
# Name: Sales, dtype: float64

# %%
df.groupby(['State'])['Sales'].sum().sort_values(ascending=False).tail(10)
# Out:
# State
# Idaho                   2417.034
# South Carolina          2063.230
# Iowa                    1675.720
# Wyoming                 1603.136
# Kansas                  1424.210
# West Virginia           1209.824
# South Dakota            1153.410
# North Dakota             919.910
# Maine                    547.330
# District of Columbia     194.830
# Name: Sales, dtype: float64

# %%
df.groupby(['City'])['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# City
# New York City    141763.6990
# Los Angeles      105274.4405
# Seattle           73149.5420
# Philadelphia      71900.4400
# San Francisco     67043.4220
# Detroit           33346.2060
# Houston           32661.4878
# Chicago           29313.1610
# Columbus          27077.8850
# Lafayette         24061.8500
# Name: Sales, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         5899 non-null   int64
#  1   Order_ID       5899 non-null   object
#  2   Order_Date     5899 non-null   datetime64[ns]
#  3   Ship_Date      5899 non-null   datetime64[ns]
#  4   Ship_Mode      5899 non-null   object
#  5   Customer_ID    5899 non-null   object
#  6   Customer_Name  5899 non-null   object
#  7   Segment        5899 non-null   object
#  8   Country        5899 non-null   object
#  9   City           5899 non-null   object
#  10  State          5899 non-null   object
#  11  Region         5899 non-null   object
#  12  Product ID     5899 non-null   object
#  13  Category       5899 non-null   object
#  14  Sub-Category   5899 non-null   object
#  15  Product_Name   5899 non-null   object
#  16  Sales          5899 non-null   float64
# ...

# %%
df.groupby(['Ship_Mode'])['Sales'].sum()
# Out:
# Ship_Mode
# First Class       222399.7194
# Same Day           83281.5010
# Second Class      268704.0640
# Standard Class    768035.5688
# Name: Sales, dtype: float64

# %%
df.groupby(['Ship_Mode'])['Profit'].sum()
# Out:
# Ship_Mode
# First Class       29749.8665
# Same Day           8808.8243
# Second Class      36936.0265
# Standard Class    99739.7266
# Name: Profit, dtype: float64

# %%
df.groupby(['Ship_Mode'])['Delivery_Days'].sum()
# Out:
# Ship_Mode
# First Class       2053
# Same Day            18
# Second Class      -696
# Standard Class   -8914
# Name: Delivery_Days, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(df.Month_Name, df.Sales)
plt.show()

# %%
plt.bar(df.Category,df.Profit)
plt.show()

# %%
plt.pie(df.Sales.head(10),labels=df.Region.head(10))
plt.show()

# %%
df.info
# Out:
# <bound method DataFrame.info of       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 1          2  CA-2019-152156 2019-11-08 2019-11-11    Second Class
# 2          3  CA-2019-138688 2019-06-12 2019-06-16    Second Class
# 3         13  CA-2020-114412 2020-04-15 2020-04-20  Standard Class
# 4         14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class
# ...      ...             ...        ...        ...             ...
# 5894    9989  CA-2020-163629 2020-11-17 2020-11-21  Standard Class
# 5895    9991  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5896    9992  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5897    9993  CA-2020-121258 2020-02-26 2020-03-03  Standard Class
# 5898    9994  CA-2020-119914 2020-05-04 2020-05-09    Second Class
#
#      Customer_ID    Customer_Name    Segment        Country         City  ...  \
# ...

# %%
plt.plot(df.Month_Name,df.Profit)
plt.show()

# %%
plt.bar(df.Profit,df.Category)
plt.show()

# %%
a=df.Profit.sort_values(ascending=False).head(10)
print(a)
# Out:
# 4002    8399.9760
# 4821    6719.9808
# 2435    5039.9856
# 5353    4946.3700
# 1544    3919.9888
# 5019    2799.9840
# 4536    2591.9568
# 3807    2504.2216
# 622     2400.9657
# 2486    2365.9818
# Name: Profit, dtype: float64

# %%
b=df.groupby(["Product_Name"])["Profit"].sum().sort_values(ascending=False).head(10)

# %%
plt.barh(a,b)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         5899 non-null   int64
#  1   Order_ID       5899 non-null   object
#  2   Order_Date     5899 non-null   datetime64[ns]
#  3   Ship_Date      5899 non-null   datetime64[ns]
#  4   Ship_Mode      5899 non-null   object
#  5   Customer_ID    5899 non-null   object
#  6   Customer_Name  5899 non-null   object
#  7   Segment        5899 non-null   object
#  8   Country        5899 non-null   object
#  9   City           5899 non-null   object
#  10  State          5899 non-null   object
#  11  Region         5899 non-null   object
#  12  Product ID     5899 non-null   object
#  13  Category       5899 non-null   object
#  14  Sub-Category   5899 non-null   object
#  15  Product_Name   5899 non-null   object
#  16  Sales          5899 non-null   float64
# ...

# %%
plt.pie(df.Sales.head(10),labels=df.Segment.head(10))
plt.show()

# %%
plt.scatter(df.Sales,df.Profit)
plt.show()

# %%
plt.hist(df.Profit,bins=5922)
plt.show()
